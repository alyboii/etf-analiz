# %%
from parsers import parse_spdr
import pandas as pd
# Out:
#   ticker                                name    shares  market_value  \
# 0   NVDA                              NVIDIA  17883160  4.077003e+09
# 1     MU                   MICRON TECHNOLOGY   3888606  3.637363e+09
# 2    AMD              ADVANCED MICRO DEVICES   7316144  3.487386e+09
# 3   AVGO                        BROADCOM INC   8451410  3.140037e+09
# 4   MRVL                  MARVELL TECHNOLOGY   9209546  2.223645e+09
# 5   INTC                   INTEL CORPORATION  23816487  2.193260e+09
# 6   AMAT                APPLIED MATERIAL INC   4194884  2.023444e+09
# 7    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING   4690005  2.004039e+09
# 8   LRCX                        LAM RESEARCH   5933533  1.890305e+09
# 9   KLAC                                 KLA   9824147  1.805383e+09
#
#      weight                  sector       location  figi  fund       date
# 0  9.473263  Information Technology  United States  None  SOXX 2026-08-27
# 1  8.451833  Information Technology  United States  None  SOXX 2026-08-27
# 2  8.101342  Information Technology  United States  None  SOXX 2026-08-27
# 3  7.290206  Information Technology  United States  None  SOXX 2026-08-27
# 4  5.167234  Information Technology  United States  None  SOXX 2026-08-27
# 5  5.097136  Information Technology  United States  None  SOXX 2026-08-27
# 6  4.696575  Information Technology  United States  None  SOXX 2026-08-27
# 7  4.656519  Information Technology         Taiwan  None  SOXX 2026-08-27
# 8  4.386141  Information Technology  United States  None  SOXX 2026-08-27
# 9  4.195874  Information Technology  United States  None  SOXX 2026-08-27
#
# Toplam ağırlık: 100.0000%
# Hisse sayısı: 30
# Tarih: 2026-08-27
#   ticker                          name   shares    weight      cusip  \
# 0     PI                    IMPINJ INC   583858  3.668514  453204109
# 1   NVDA                   NVIDIA CORP   357571  3.047557  67066G104
# 2   AMBA                 AMBARELLA INC  1143825  3.042904  G037AX101
# 3    AMD        ADVANCED MICRO DEVICES   158030  2.816113  007903107
# 4     MU         MICRON TECHNOLOGY INC    80123  2.801836  595112103
# 5   QRVO                     QORVO INC   752763  2.706673  74736K101
# 6   CRDO  CREDO TECHNOLOGY GROUP HOLDI   300912  2.702574  G25457105
# 7   SLAB      SILICON LABORATORIES INC   328266  2.686975  826919102
# 8   AVGO                  BROADCOM INC   192106  2.668328  11135F101
# 9   OLED        UNIVERSAL DISPLAY CORP   818492  2.596325  91347P105
#
#   market_value sector location  figi fund       date
# 0         None   None     None  None  XSD 2026-08-27
# 1         None   None     None  None  XSD 2026-08-27
# 2         None   None     None  None  XSD 2026-08-27
# 3         None   None     None  None  XSD 2026-08-27
# 4         None   None     None  None  XSD 2026-08-27
# 5         None   None     None  None  XSD 2026-08-27
# 6         None   None     None  None  XSD 2026-08-27
# 7         None   None     None  None  XSD 2026-08-27
# 8         None   None     None  None  XSD 2026-08-27
# 9         None   None     None  None  XSD 2026-08-27
#
# Toplam: 100.0000% | 47 hisse
# Tarih: 2026-08-27

# %%
tum = pd.concat([smh, soxx, xsd], ignore_index=True)

print(tum.groupby("fund")["weight"].agg(["count", "sum"]))
print()
print("Kolonlar:", tum.columns.tolist())
print("Boş kolon kontrolü:")
print(tum.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tum = pd.concat([smh, soxx, xsd], ignore_index=True)
#       3 print(tum.groupby("fund")["weight"].agg(["count", "sum"]))
#       4 print()
#
# NameError: name 'smh' is not defined
