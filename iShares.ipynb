# %%
from parsers import  parse_ishares
# Out:
#   ticker                                name    shares  market_value  \
# 0   NVDA                              NVIDIA  17883160  4.077003e+09
# 1     MU                   MICRON TECHNOLOGY   3888606  3.637363e+09
# 2    AMD              ADVANCED MICRO DEVICES   7316144  3.487386e+09
# 3   AVGO                        BROADCOM INC   8451410  3.140037e+09
# 4   MRVL                  MARVELL TECHNOLOGY   9209546  2.223645e+09
# 5   INTC                   INTEL CORPORATION  23816487  2.193260e+09
# 6   AMAT                APPLIED MATERIAL INC   4194884  2.023444e+09
# 7    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING   4690005  2.004039e+09
# 8   LRCX                        LAM RESEARCH   5933533  1.890305e+09
# 9   KLAC                                 KLA   9824147  1.805383e+09
#
#      weight                  sector       location  figi  fund       date
# 0  9.473263  Information Technology  United States  None  SOXX 2026-08-27
# ...

# %%
soxx = parse_ishares("data/raw/SOXX_holdings.csv","SOXX")
print(soxx)
# Out:
#    ticker                                name    shares  market_value  \
# 0    NVDA                              NVIDIA  17883160  4.077003e+09
# 1      MU                   MICRON TECHNOLOGY   3888606  3.637363e+09
# 2     AMD              ADVANCED MICRO DEVICES   7316144  3.487386e+09
# 3    AVGO                        BROADCOM INC   8451410  3.140037e+09
# 4    MRVL                  MARVELL TECHNOLOGY   9209546  2.223645e+09
# 5    INTC                   INTEL CORPORATION  23816487  2.193260e+09
# 6    AMAT                APPLIED MATERIAL INC   4194884  2.023444e+09
# 7     TSM  TAIWAN SEMICONDUCTOR MANUFACTURING   4690005  2.004039e+09
# 8    LRCX                        LAM RESEARCH   5933533  1.890305e+09
# 9    KLAC                                 KLA   9824147  1.805383e+09
# 10    ADI                      ANALOG DEVICES   4561962  1.708546e+09
# 11    TXN                TEXAS INSTRUMENT INC   6176192  1.646202e+09
# ...

# %%
soxx.head()
# Out:
#   ticker                    name    shares  market_value    weight  \
# 0   NVDA                  NVIDIA  17883160  4.077003e+09  9.473263
# 1     MU       MICRON TECHNOLOGY   3888606  3.637363e+09  8.451833
# 2    AMD  ADVANCED MICRO DEVICES   7316144  3.487386e+09  8.101342
# 3   AVGO            BROADCOM INC   8451410  3.140037e+09  7.290206
# 4   MRVL      MARVELL TECHNOLOGY   9209546  2.223645e+09  5.167234
#
#                    sector       location  figi  fund       date
# 0  Information Technology  United States  None  SOXX 2026-08-27
# 1  Information Technology  United States  None  SOXX 2026-08-27
# 2  Information Technology  United States  None  SOXX 2026-08-27
# 3  Information Technology  United States  None  SOXX 2026-08-27
# 4  Information Technology  United States  None  SOXX 2026-08-27
